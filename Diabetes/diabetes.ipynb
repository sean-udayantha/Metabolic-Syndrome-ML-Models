# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # **Getting Started**
#
# **Title : Diabetes Prediction Prediction**
#
#   **Diabetes Prediction Status :**
#
#   0 --> no
#   1 -->  yes

# %% [markdown]
# ### **DataFraming**
#
# **Read .csv file into pandas**

# %%
data = pd.read_csv('C:\\Users\\AKILA\\PycharmProjects\\Murtaza\'s_Workshop\\Chapter 7 - medical\\Diabetes\\diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## **Exploratory data analysis**

# %%
#Shape of data 
print(data.shape)
#dtypes of data 
print(data.dtypes)
# Out:
# (768, 9)
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Checking for null values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### **Checking Duplicates**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### **Dropping Duplicates**

# %%
data = data.drop_duplicates()

# %% [markdown]
# # **Transformation**

# %%
# Value_counts of output
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# output & output Count
import seaborn as sns
sns.countplot(x='Outcome',hue='Outcome',data=data)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
# age & output
import seaborn as sns
sns.countplot(x='Age',hue='Outcome',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
# let's see how data is distributed for every column
import matplotlib.pyplot as plt

plt.figure(figsize = (20, 25))
plotnumber = 1
for column in data:
    if plotnumber <= 9:
        ax = plt.subplot(3, 3, plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize = 15)
        
    plotnumber += 1
plt.show()
# Out:
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_35664\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])

# %%
plt.figure(figsize=(9,9))
sns.histplot(data[['DiabetesPedigreeFunction', 'Outcome']], x = "DiabetesPedigreeFunction", hue="Outcome")
plt.title("")
plt.show()

# %% [markdown]
# **We can see that the distribution of data is normal ! lets move for the Model preparation.** 🚀

# %% [markdown]
# ### Find Correlations in Data Set

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(), annot=True);
plt.show()

# %% [markdown]
# # **Model Preparation**
#
# Spilt into X & Y

# %%
# separating the data and target
X = data.drop(columns=['Outcome'],axis=1)
y = data['Outcome']

# %%
print("The shape of X is " , X.shape)
print("The shape of Y is " , y.shape)
# Out:
# The shape of X is  (768, 8)
# The shape of Y is  (768,)

# %%
from sklearn.model_selection import train_test_split
# separating into train and testing
X_train, X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)
print("Shape of X_train is " ,X_train.shape)
print("Shape of X_test  is " ,X_test.shape)
print("Shape of Y_train is " ,Y_train.shape)
print("Shape of Y_test  is " ,Y_test.shape)
# Out:
# Shape of X_train is  (614, 8)
# Shape of X_test  is  (154, 8)
# Shape of Y_train is  (614,)
# Shape of Y_test  is  (154,)

# %%
# After statify Y train & test values
print(Y_train.value_counts())
print(Y_test.value_counts())
# Out:
# 0    400
# 1    214
# Name: Outcome, dtype: int64
# 0    100
# 1     54
# Name: Outcome, dtype: int64

# %% [markdown]
# # **Feature Scalilng**

# %%
# scaling the data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.85135507, -0.98013068, -0.40478372, ..., -0.60767846,
#          0.31079384, -0.79216928],
#        [ 0.35657564,  0.16144422,  0.46536842, ..., -0.30213902,
#         -0.11643851,  0.56103382],
#        [-0.5493724 , -0.50447447, -0.62232176, ...,  0.3725939 ,
#         -0.76486207, -0.70759409],
#        ...,
#        [-0.85135507, -0.75815778,  0.03029235, ...,  0.77997981,
#         -0.78607218, -0.28471812],
#        [ 1.86648903, -0.31421198,  0.03029235, ..., -0.56948603,
#         -1.01938346,  0.56103382],
#        [ 0.05459296,  0.73223168, -0.62232176, ..., -0.31486983,
#         -0.57700104,  0.30730824]])

# %%
from sklearn.ensemble import RandomForestClassifier
randf=RandomForestClassifier(n_estimators=100)
randf.fit(X_train,Y_train)
y_pred=randf.predict(X_test)

# %%
randf.feature_importances_
# Out:
# array([0.08388298, 0.26720637, 0.08875326, 0.07036931, 0.08042823,
#        0.15770886, 0.12021396, 0.13143703])

# %%
features = data.columns.values.tolist()[0:8] #Dropping Dependent Variable Heart Attack dataset
feature_pro = pd.Series(randf.feature_importances_,index=features).sort_values(ascending=False)

# %%
feature_pro
# Out:
# Glucose                     0.267206
# BMI                         0.157709
# Age                         0.131437
# DiabetesPedigreeFunction    0.120214
# BloodPressure               0.088753
# Pregnancies                 0.083883
# Insulin                     0.080428
# SkinThickness               0.070369
# dtype: float64

# %% [markdown]
# ## Feature Importances Vizualizing

# %%
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_pro, y=feature_pro.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **Model Training**
#
# **We will train different model after the evaluation of model we will select out best model for production.**
#
# 1.   Logistic Regression
# 2.   KNN
# 3.   SVC
# 3.   Decision Tree
# 4.   Random Forest Regressor
# 5.   XgBoost
# 6.   Gradient Boosting

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

lr = LogisticRegression()
lr.fit(X_train, Y_train)
y_pred = lr.predict(X_test)

lr_train_acc = accuracy_score(Y_train, lr.predict(X_train))
lr_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Logistic Regression Model is {lr_train_acc}")
print(f"Test Accuracy of Logistic Regression Model is {lr_test_acc}")
# Out:
# Training Accuracy of Logistic Regression Model is 0.7915309446254072
# Test Accuracy of Logistic Regression Model is 0.7142857142857143

# %%
# confusion matrix 
confusion_matrix(Y_test, y_pred)
# Out:
# array([[82, 18],
#        [26, 28]], dtype=int64)

# %%
# classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79       100
#            1       0.61      0.52      0.56        54
#
#     accuracy                           0.71       154
#    macro avg       0.68      0.67      0.67       154
# weighted avg       0.71      0.71      0.71       154

# %% [markdown]
# ## **SVC**

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, Y_train)

y_pred = svc.predict(X_test)

svc_train_acc = accuracy_score(Y_train, svc.predict(X_train))
svc_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of SVC Model is {svc_train_acc}")
print(f"Test Accuracy of SVC Model is {svc_test_acc}")
# Out:
# Training Accuracy of SVC Model is 0.8355048859934854
# Test Accuracy of SVC Model is 0.7532467532467533

# %%
# confusion matrix
confusion_matrix(Y_test, y_pred)
# Out:
# array([[83, 17],
#        [21, 33]], dtype=int64)

# %%
# classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       100
#            1       0.66      0.61      0.63        54
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.72      0.72       154
# weighted avg       0.75      0.75      0.75       154

# %% [markdown]
# ## **DecisionTreeClassifier**

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)

y_pred = dtc.predict(X_test)

dtc_train_acc = accuracy_score(Y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Decision Tree Model is {dtc_train_acc}")
print(f"Test Accuracy of Decision Tree Model is {dtc_test_acc}")
# Out:
# Training Accuracy of Decision Tree Model is 1.0
# Test Accuracy of Decision Tree Model is 0.7207792207792207

# %%
# confusion matrix
confusion_matrix(Y_test, y_pred)
# Out:
# array([[84, 16],
#        [27, 27]], dtype=int64)

# %%
# classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       100
#            1       0.63      0.50      0.56        54
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.67      0.68       154
# weighted avg       0.71      0.72      0.71       154

# %% [markdown]
# ## **Hyper parameter tuning**

# %%
# hyper parameter tuning

from sklearn.model_selection import GridSearchCV

grid_params = {
    'criterion' : ['gini', 'entropy'],

    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(dtc, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
# best parameters and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 9, 'min_samples_split': 2}
# 0.7606690657070506

# %%
dtc = grid_search.best_estimator_
y_pred = dtc.predict(X_test)
dtc_train_acc = accuracy_score(Y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Decesion Tree Model is {dtc_train_acc}")
print(f"Test Accuracy of Decesion Tree Model is {dtc_test_acc}")
# Out:
# Training Accuracy of Decesion Tree Model is 0.8630705394190872
# Test Accuracy of Decesion Tree Model is 0.7868852459016393

# %% [markdown]
# **Visualization the DTC tree.**

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dtc,filled=True)
# Out:
# [Text(0.6080210772833724, 0.9705882352941176, 'x[1] <= 1.065\ngini = 0.454\nsamples = 614\nvalue = [400, 214]'),
#  Text(0.27195550351288056, 0.9117647058823529, 'x[5] <= -0.589\ngini = 0.379\nsamples = 515\nvalue = [384, 131]'),
#  Text(0.06088992974238876, 0.8529411764705882, 'x[1] <= 0.97\ngini = 0.097\nsamples = 137\nvalue = [130, 7]'),
#  Text(0.05152224824355972, 0.7941176470588235, 'x[5] <= -2.912\ngini = 0.084\nsamples = 136\nvalue = [130, 6]'),
#  Text(0.01873536299765808, 0.7352941176470589, 'x[0] <= 1.112\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.00936768149882904, 0.6764705882352942, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.02810304449648712, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08430913348946135, 0.7352941176470589, 'x[1] <= 0.399\ngini = 0.061\nsamples = 127\nvalue = [123, 4]'),
#  Text(0.0468384074941452, 0.6764705882352942, 'x[5] <= -0.646\ngini = 0.035\nsamples = 112\nvalue = [110, 2]'),
#  Text(0.02810304449648712, 0.6176470588235294, 'x[6] <= 0.6\ngini = 0.019\nsamples = 105\nvalue = [104, 1]'),
#  Text(0.01873536299765808, 0.5588235294117647, 'gini = 0.0\nsamples = 89\nvalue = [89, 0]'),
#  Text(0.03747072599531616, 0.5588235294117647, 'x[6] <= 0.691\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.02810304449648712, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0468384074941452, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.06557377049180328, 0.6176470588235294, 'x[7] <= 0.899\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.05620608899297424, 0.5588235294117647, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.07494145199063232, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12177985948477751, 0.6764705882352942, 'x[1] <= 0.431\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.10304449648711944, 0.6176470588235294, 'x[5] <= -0.907\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0936768149882904, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11241217798594848, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1405152224824356, 0.6176470588235294, 'x[2] <= -0.731\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.13114754098360656, 0.5588235294117647, 'x[7] <= 0.73\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12177985948477751, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1405152224824356, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14988290398126464, 0.5588235294117647, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.0702576112412178, 0.7941176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.48302107728337235, 0.8529411764705882, 'x[7] <= -0.242\ngini = 0.441\nsamples = 378\nvalue = [254, 124]'),
#  Text(0.32786885245901637, 0.7941176470588235, 'x[1] <= 0.209\ngini = 0.332\nsamples = 205\nvalue = [162, 43]'),
#  Text(0.2576112412177986, 0.7352941176470589, 'x[5] <= 1.709\ngini = 0.238\nsamples = 159\nvalue = [137, 22]'),
#  Text(0.22482435597189696, 0.6764705882352942, 'x[6] <= 0.097\ngini = 0.206\nsamples = 154\nvalue = [136, 18]'),
#  Text(0.1873536299765808, 0.6176470588235294, 'x[0] <= 0.961\ngini = 0.111\nsamples = 102\nvalue = [96, 6]'),
#  Text(0.1686182669789227, 0.5588235294117647, 'x[2] <= -2.58\ngini = 0.078\nsamples = 99\nvalue = [95, 4]'),
#  Text(0.1592505854800937, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17798594847775176, 0.5, 'x[4] <= -0.378\ngini = 0.059\nsamples = 98\nvalue = [95, 3]'),
#  Text(0.1686182669789227, 0.4411764705882353, 'x[4] <= -0.415\ngini = 0.133\nsamples = 42\nvalue = [39, 3]'),
#  Text(0.14988290398126464, 0.38235294117647056, 'x[1] <= -0.298\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(0.1405152224824356, 0.3235294117647059, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.1592505854800937, 0.3235294117647059, 'x[0] <= -0.398\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.14988290398126464, 0.2647058823529412, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1686182669789227, 0.2647058823529412, 'x[3] <= -0.933\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.1592505854800937, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.17798594847775176, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1873536299765808, 0.38235294117647056, 'x[1] <= -1.155\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17798594847775176, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19672131147540983, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1873536299765808, 0.4411764705882353, 'gini = 0.0\nsamples = 56\nvalue = [56, 0]'),
#  Text(0.20608899297423888, 0.5588235294117647, 'x[1] <= -0.124\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.19672131147540983, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2154566744730679, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.26229508196721313, 0.6176470588235294, 'x[5] <= 0.029\ngini = 0.355\nsamples = 52\nvalue = [40, 12]'),
#  Text(0.2529274004683841, 0.5588235294117647, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.2716627634660422, 0.5588235294117647, 'x[7] <= -0.496\ngini = 0.469\nsamples = 32\nvalue = [20, 12]'),
#  Text(0.24355971896955503, 0.5, 'x[6] <= 0.202\ngini = 0.417\nsamples = 27\nvalue = [19, 8]'),
#  Text(0.2154566744730679, 0.4411764705882353, 'x[5] <= 0.258\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.20608899297423888, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.22482435597189696, 0.38235294117647056, 'x[1] <= -0.33\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2154566744730679, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.234192037470726, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2716627634660422, 0.4411764705882353, 'x[6] <= 2.406\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.26229508196721313, 0.38235294117647056, 'x[5] <= 0.57\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.2529274004683841, 0.3235294117647059, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2716627634660422, 0.3235294117647059, 'x[5] <= 0.602\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.26229508196721313, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2810304449648712, 0.2647058823529412, 'x[7] <= -0.834\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.2716627634660422, 0.20588235294117646, 'x[1] <= -0.933\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.26229508196721313, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2810304449648712, 0.14705882352941177, 'x[6] <= 0.946\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2716627634660422, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2903981264637002, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2903981264637002, 0.20588235294117646, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2810304449648712, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2997658079625293, 0.5, 'x[5] <= 0.468\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2903981264637002, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3091334894613583, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2903981264637002, 0.6764705882352942, 'x[6] <= 1.111\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2810304449648712, 0.6176470588235294, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.2997658079625293, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3981264637002342, 0.7352941176470589, 'x[2] <= 0.193\ngini = 0.496\nsamples = 46\nvalue = [25, 21]'),
#  Text(0.3559718969555035, 0.6764705882352942, 'x[0] <= -1.002\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.34660421545667447, 0.6176470588235294, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.36533957845433257, 0.6176470588235294, 'x[2] <= -0.024\ngini = 0.5\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.34660421545667447, 0.5588235294117647, 'x[2] <= -0.568\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.3372365339578454, 0.5, 'x[5] <= -0.27\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.32786885245901637, 0.4411764705882353, 'x[2] <= -2.526\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3185011709601874, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3372365339578454, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34660421545667447, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3559718969555035, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3840749414519906, 0.5588235294117647, 'x[6] <= -0.477\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.3747072599531616, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39344262295081966, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.44028103044496486, 0.6764705882352942, 'x[5] <= 1.455\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.4309133489461358, 0.6176470588235294, 'x[0] <= 0.206\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.4215456674473068, 0.5588235294117647, 'x[2] <= 1.009\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.41217798594847777, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.4309133489461358, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44028103044496486, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4496487119437939, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6381733021077284, 0.7941176470588235, 'x[1] <= -0.425\ngini = 0.498\nsamples = 173\nvalue = [92, 81]'),
#  Text(0.5269320843091335, 0.7352941176470589, 'x[6] <= 0.479\ngini = 0.41\nsamples = 66\nvalue = [47, 19]'),
#  Text(0.48711943793911006, 0.6764705882352942, 'x[7] <= -0.158\ngini = 0.305\nsamples = 48\nvalue = [39, 9]'),
#  Text(0.468384074941452, 0.6176470588235294, 'x[6] <= -0.001\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.45901639344262296, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.477751756440281, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5058548009367682, 0.6176470588235294, 'x[1] <= -2.93\ngini = 0.263\nsamples = 45\nvalue = [38, 7]'),
#  Text(0.4964871194379391, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5152224824355972, 0.5588235294117647, 'x[2] <= -2.961\ngini = 0.236\nsamples = 44\nvalue = [38, 6]'),
#  Text(0.5058548009367682, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5245901639344263, 0.5, 'x[0] <= -0.7\ngini = 0.206\nsamples = 43\nvalue = [38, 5]'),
#  Text(0.5011709601873536, 0.4411764705882353, 'x[1] <= -0.584\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4918032786885246, 0.38235294117647056, 'x[5] <= 0.194\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.48243559718969553, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5011709601873536, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5105386416861827, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5480093676814989, 0.4411764705882353, 'x[5] <= -0.124\ngini = 0.145\nsamples = 38\nvalue = [35, 3]'),
#  Text(0.5292740046838408, 0.38235294117647056, 'x[0] <= 2.319\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.5199063231850117, 0.3235294117647059, 'x[5] <= -0.175\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.5105386416861827, 0.2647058823529412, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5292740046838408, 0.2647058823529412, 'x[1] <= -0.552\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5199063231850117, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5386416861826698, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5386416861826698, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5667447306791569, 0.38235294117647056, 'x[7] <= 1.491\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.5573770491803278, 0.3235294117647059, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.5761124121779859, 0.3235294117647059, 'x[2] <= 0.248\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5667447306791569, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.585480093676815, 0.2647058823529412, 'x[6] <= -0.412\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5761124121779859, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.594847775175644, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5667447306791569, 0.6764705882352942, 'x[2] <= 0.955\ngini = 0.494\nsamples = 18\nvalue = [8, 10]'),
#  Text(0.5573770491803278, 0.6176470588235294, 'x[4] <= -0.503\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.5480093676814989, 0.5588235294117647, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5667447306791569, 0.5588235294117647, 'x[4] <= 0.059\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.5573770491803278, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5761124121779859, 0.5, 'x[6] <= 2.077\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5667447306791569, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.585480093676815, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5761124121779859, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7494145199063232, 0.7352941176470589, 'x[5] <= 1.391\ngini = 0.487\nsamples = 107\nvalue = [45, 62]'),
#  Text(0.7306791569086651, 0.6764705882352942, 'x[5] <= 1.028\ngini = 0.497\nsamples = 95\nvalue = [44, 51]'),
#  Text(0.7213114754098361, 0.6176470588235294, 'x[6] <= 0.152\ngini = 0.493\nsamples = 91\nvalue = [40, 51]'),
#  Text(0.6510538641686182, 0.5588235294117647, 'x[0] <= -0.7\ngini = 0.498\nsamples = 60\nvalue = [32, 28]'),
#  Text(0.6416861826697893, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6604215456674473, 0.5, 'x[7] <= 0.434\ngini = 0.483\nsamples = 54\nvalue = [32, 22]'),
#  Text(0.6229508196721312, 0.4411764705882353, 'x[2] <= -2.199\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.6135831381733021, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6323185011709602, 0.38235294117647056, 'x[0] <= -0.096\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.6135831381733021, 0.3235294117647059, 'x[3] <= 0.046\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6042154566744731, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6229508196721312, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6510538641686182, 0.3235294117647059, 'x[6] <= -0.656\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.6416861826697893, 0.2647058823529412, 'x[3] <= 0.961\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6323185011709602, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6510538641686182, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6604215456674473, 0.2647058823529412, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.6978922716627635, 0.4411764705882353, 'x[5] <= -0.487\ngini = 0.5\nsamples = 37\nvalue = [18, 19]'),
#  Text(0.6791569086651054, 0.38235294117647056, 'x[2] <= 0.139\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.6697892271662763, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6885245901639344, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7166276346604216, 0.38235294117647056, 'x[1] <= -0.156\ngini = 0.487\nsamples = 31\nvalue = [13, 18]'),
#  Text(0.7072599531615925, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7259953161592506, 0.3235294117647059, 'x[1] <= 0.304\ngini = 0.5\nsamples = 26\nvalue = [13, 13]'),
#  Text(0.6978922716627635, 0.2647058823529412, 'x[4] <= 0.291\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.6885245901639344, 0.20588235294117646, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7072599531615925, 0.20588235294117646, 'x[7] <= 0.561\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6978922716627635, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7166276346604216, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7540983606557377, 0.2647058823529412, 'x[6] <= -0.671\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.7447306791569087, 0.20588235294117646, 'x[6] <= -1.003\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.7353629976580797, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7540983606557377, 0.14705882352941177, 'x[5] <= -0.289\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.7447306791569087, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7634660421545667, 0.08823529411764706, 'x[7] <= 2.887\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.7540983606557377, 0.029411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7728337236533958, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7634660421545667, 0.20588235294117646, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7915690866510539, 0.5588235294117647, 'x[4] <= 0.946\ngini = 0.383\nsamples = 31\nvalue = [8, 23]'),
#  Text(0.7728337236533958, 0.5, 'x[7] <= 1.999\ngini = 0.227\nsamples = 23\nvalue = [3, 20]'),
#  Text(0.7634660421545667, 0.4411764705882353, 'x[2] <= -0.024\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.7540983606557377, 0.38235294117647056, 'x[1] <= 0.003\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7447306791569087, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7634660421545667, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7728337236533958, 0.38235294117647056, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.7822014051522248, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.810304449648712, 0.5, 'x[5] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.8009367681498829, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.819672131147541, 0.4411764705882353, 'x[4] <= 1.16\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.810304449648712, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8290398126463701, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7400468384074942, 0.6176470588235294, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7681498829039812, 0.6764705882352942, 'x[6] <= -0.815\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.7587822014051522, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7775175644028103, 0.6176470588235294, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.9440866510538641, 0.9117647058823529, 'x[5] <= -1.13\ngini = 0.271\nsamples = 99\nvalue = [16, 83]'),
#  Text(0.9347189695550351, 0.8529411764705882, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9534543325526932, 0.8529411764705882, 'x[4] <= 4.323\ngini = 0.247\nsamples = 97\nvalue = [14, 83]'),
#  Text(0.9256440281030445, 0.7941176470588235, 'x[7] <= 2.464\ngini = 0.223\nsamples = 94\nvalue = [12, 82]'),
#  Text(0.8981264637002342, 0.7352941176470589, 'x[6] <= -1.039\ngini = 0.198\nsamples = 90\nvalue = [10, 80]'),
#  Text(0.8711943793911007, 0.6764705882352942, 'x[3] <= -0.649\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8618266978922716, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8805620608899297, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9250585480093677, 0.6764705882352942, 'x[2] <= 1.227\ngini = 0.169\nsamples = 86\nvalue = [8, 78]'),
#  Text(0.8992974238875878, 0.6176470588235294, 'x[7] <= 1.238\ngini = 0.139\nsamples = 80\nvalue = [6, 74]'),
#  Text(0.8758782201405152, 0.5588235294117647, 'x[6] <= -0.524\ngini = 0.091\nsamples = 63\nvalue = [3, 60]'),
#  Text(0.8665105386416861, 0.5, 'x[6] <= -0.63\ngini = 0.305\nsamples = 16\nvalue = [3, 13]'),
#  Text(0.8571428571428571, 0.4411764705882353, 'x[0] <= 1.715\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.8477751756440282, 0.38235294117647056, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8665105386416861, 0.38235294117647056, 'x[7] <= 0.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8571428571428571, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8758782201405152, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8758782201405152, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8852459016393442, 0.5, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.9227166276346604, 0.5588235294117647, 'x[7] <= 1.449\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.9039812646370023, 0.5, 'x[4] <= -0.42\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8946135831381733, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9133489461358314, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9414519906323185, 0.5, 'x[0] <= -1.002\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.9320843091334895, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9508196721311475, 0.4411764705882353, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.9508196721311475, 0.6176470588235294, 'x[1] <= 1.779\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.9414519906323185, 0.5588235294117647, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9601873536299765, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9531615925058547, 0.7352941176470589, 'x[2] <= 0.683\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9437939110070258, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9625292740046838, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9812646370023419, 0.7941176470588235, 'x[7] <= -0.327\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9718969555035128, 0.7352941176470589, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.990632318501171, 0.7352941176470589, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ## **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion = 'gini', max_depth = 3, max_features = 'sqrt', min_samples_leaf = 2, min_samples_split = 4, n_estimators = 180)
rand_clf.fit(X_train, Y_train)

y_pred = rand_clf.predict(X_test)

rand_clf_train_acc = accuracy_score(Y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Random Forest Model is {rand_clf_train_acc}")
print(f"Test Accuracy of Random Forest Model is {rand_clf_test_acc}")
# Out:
# Training Accuracy of Random Forest Model is 0.7931596091205212
# Test Accuracy of Random Forest Model is 0.7337662337662337

# %% [markdown]
# ## **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
k_model = KNeighborsClassifier(n_neighbors=16)
kfitModel = k_model.fit(X_train, Y_train)

# accuracy score on training data

kX_train_prediction = kfitModel.predict(X_train)
training_data_accuray = accuracy_score(kX_train_prediction,Y_train)
print('Accuracy on training data  : ', training_data_accuray)

# accuracy score on testing data
kX_test_prediction = kfitModel.predict(X_test)
kx_lgr_test_data_accuray = accuracy_score(kX_test_prediction,Y_test)
print('Accuracy on test data      : ', kx_lgr_test_data_accuray)
# Out:
# Accuracy on training data  :  0.7866449511400652
# Accuracy on test data      :  0.7337662337662337

# %% [markdown]
# ## **GradientBoostingClassifier**

# %%
#Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

parameters = {
    'loss': ['deviance', 'exponential'],
    'learning_rate': [0.001, 0.1, 1, 10],
    'n_estimators': [100, 150, 180, 200]
}

grid_search = GridSearchCV(gb, parameters, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.1, 1, 10],
#                          'loss': ['deviance', 'exponential'],
#                          'n_estimators': [100, 150, 180, 200]},
#              verbose=1)

# %%
# best parameter and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'learning_rate': 0.1, 'loss': 'exponential', 'n_estimators': 100}
# 0.7590430494468878

# %%
gb = GradientBoostingClassifier(learning_rate = 1, loss = 'exponential', n_estimators = 180)
gb.fit(X_train, Y_train)

y_pred = gb.predict(X_test)

gb_train_acc = accuracy_score(Y_train, gb.predict(X_train))
gb_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Gradient Boosting Classifier Model is {gb_train_acc}")
print(f"Test Accuracy of Gradient Boosting Classifier Model is {gb_test_acc}")
# Out:
# Training Accuracy of Gradient Boosting Classifier Model is 1.0
# Test Accuracy of Gradient Boosting Classifier Model is 0.7077922077922078

# %%
# confusion matrix

confusion_matrix(Y_test, y_pred)
# Out:
# array([[76, 24],
#        [21, 33]], dtype=int64)

# %%
# classification report

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77       100
#            1       0.58      0.61      0.59        54
#
#     accuracy                           0.71       154
#    macro avg       0.68      0.69      0.68       154
# weighted avg       0.71      0.71      0.71       154

# %% [markdown]
# ## **XGB Classifier**

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(booster = 'gblinear', learning_rate = 1, n_estimators = 10)
xgb.fit(X_train, Y_train)

y_pred = xgb.predict(X_test)

xgb_train_acc = accuracy_score(Y_train, xgb.predict(X_train))
xgb_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of XGB Model is {xgb_train_acc}")
print(f"Test Accuracy of XGB Model is {xgb_test_acc}")
# Out:
# Training Accuracy of XGB Model is 0.7947882736156352
# Test Accuracy of XGB Model is 0.7142857142857143

# %%
models = ['Logistic Regression', 'KNN', 'SVC', 'Decision Tree', 'Random Forest','Gradient Boosting', 'XgBoost']
scores = [lr_test_acc, kx_lgr_test_data_accuray, svc_test_acc, dtc_test_acc, rand_clf_test_acc,gb_test_acc, xgb_test_acc]

models = pd.DataFrame({'Model' : models, 'Score' : scores})


models.sort_values(by = 'Score', ascending = False)
# Out:
#                  Model     Score
# 2                  SVC  0.753247
# 1                  KNN  0.733766
# 4        Random Forest  0.733766
# 3        Decision Tree  0.720779
# 0  Logistic Regression  0.714286
# 6              XgBoost  0.714286
# 5    Gradient Boosting  0.707792

# %%
plt.figure(figsize = (18, 8))

sns.barplot(x = 'Model', y = 'Score', data = models)
plt.show()

# %% [markdown]
# ### ***SVC gives us the best result so we will save this model for production but it overfited then i select Random Forest .***

# %%
import pickle

# %%
# save the model to disk
filename = 'diabetes_model.sav'
pickle.dump(models, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model
# Out:
#                  Model     Score
# 0  Logistic Regression  0.714286
# 1                  KNN  0.733766
# 2                  SVC  0.753247
# 3        Decision Tree  0.720779
# 4        Random Forest  0.733766
# 5    Gradient Boosting  0.707792
# 6              XgBoost  0.714286

# %% [markdown]
# ## Create Pickle File for Random Forest Model

# %%
import pickle
# open a file, where you ant to store the data
file = open('diabetes_model.pkl', 'wb')

# dump information to that file
# lr
# svc
# dtc -
# grid_search
# k_model
# gb
# xgb
pickle.dump(dtc, file)  #Selecting Random Forest as the Model because of Giving highest Accuracy after svc

# %%
#Reading the Pickle file for to certify model was imported Successfully
model = open('diabetes_model.pkl','rb')
lrModel= pickle.load(model)

# %%
# Prediction Parameters testing using the imported Model
y_prediction = lrModel.predict(X_test)

# %%
svc_acc = accuracy_score(Y_test, y_prediction)

# %%
svc_acc
# Out:
# 0.7207792207792207

# %%
## Example for Predicting the Heart Attack Analysis
import numpy as np

 #More chance
X_New = [6,148,72,35,0,33.6,0.627,50]
X_New = np.reshape(X_New, (1, -1))

y_New = lrModel.predict(X_New)


#Less chance
X_2 = [10,115,0,0,0,35.3,0.134,29]
X_2 = np.reshape(X_2, (1, -1))

y_2 = lrModel.predict(X_2)

# %%
print(y_New)
# Out:
# [1]

# %%
print(y_2)
# Out:
# [0]

# %% [markdown]
# ## ***.hy file***

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import joblib

# %%
# Save the model to a .hy file
file = open('heart_model.hy', 'wb')
joblib.dump(rand_clf, file)
# file.close()

# Load the model from the .hy file
model = open('heart_model.hy', 'rb')
loaded_model = joblib.load(model)
# model.close()

# Assuming X_test is your test data
predictions = loaded_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, predictions)
print(f"Accuracy of the loaded model is {accuracy}")
# Out:
# Accuracy of the loaded model is 0.819672131147541

# %% [markdown]
# **So this will Verify that Our Imported hy file provides the desired out put for the Heart Attack Analysis & Prediction Dataset for Prdiction Purpose**

# %%
import numpy as np
import joblib

# %%
loaded_model = joblib.load('heart_model.hy')

# %%
X_New = np.array([55,1,0,140,217,0,1,111,1,5.6,0,0,3])
X_New = np.reshape(X_New, (1, -1))

# %%
y_New = loaded_model.predict(X_New)

# %%
if y_New == 0:
    print("Less chance of heart attack")
else:
    print("More chance of heart attack")
# Out:
# Less chance of heart attack

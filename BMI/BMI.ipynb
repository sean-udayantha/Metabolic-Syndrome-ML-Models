# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # **Getting Started**
#
# **Title : BMI level Prediction**
#
#   **BMI level Status :**
#
#   0 - Extremely Weak
#   1 - Weak
#   2 - Normal
#   3 - Overweight
#   4 - Obesity
#   5 - Extreme Obesity

# %% [markdown]
# ### **DataFraming**
#
# **Read .csv file into pandas**

# %%
data = pd.read_csv('C:\\Users\\AKILA\\PycharmProjects\\Murtaza\'s_Workshop\\Chapter 7 - medical\\bmi.csv')
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %% [markdown]
# ## **Exploratory data analysis**

# %%
#Shape of data 
print(data.shape)
#dtypes of data 
print(data.dtypes)
# Out:
# (500, 4)
# Gender    object
# Height     int64
# Weight     int64
# Index      int64
# dtype: object

# %%
# Info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
# Checking for null values
data.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %% [markdown]
# ### **Checking Duplicates**

# %%
data.duplicated().sum()
# Out:
# 11

# %% [markdown]
# ### **Dropping Duplicates**

# %%
data = data.drop_duplicates()

# %% [markdown]
# # **Transformation**

# %%
# label encoding
data.replace({"Gender":{'Male':0,'Female':1}},inplace=True)
# printing the first 5 rows of the dataframe
data.head(5)
# Out:
#    Gender  Height  Weight  Index
# 0       0     174      96      4
# 1       0     189      87      2
# 2       1     185     110      4
# 3       1     195     104      3
# 4       0     149      61      3

# %%
# Value_counts of index
data['Index'].value_counts()
# Out:
# 5    195
# 4    128
# 2     69
# 3     64
# 1     20
# 0     13
# Name: Index, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# Index & Index Count
import seaborn as sns
sns.countplot(x='Index',hue='Index',data=data)
# Out:
# <Axes: xlabel='Index', ylabel='count'>

# %%
# Gender & Index
import seaborn as sns
sns.countplot(x='Gender',hue='Index',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# let's see how data is distributed for every column
import matplotlib.pyplot as plt

plt.figure(figsize = (20, 25))
plotnumber = 1
for column in data:
    if plotnumber <= 9:
        ax = plt.subplot(3, 3, plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize = 15)
        
    plotnumber += 1
plt.show()
# Out:
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_49392\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_49392\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_49392\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\AKILA\AppData\Local\Temp\ipykernel_49392\370700729.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])

# %%
plt.figure(figsize=(9,9))
sns.histplot(data[['Weight', 'Index']], x = "Weight", hue="Index")
plt.title("")
plt.show()

# %% [markdown]
# **We can see that the distribution of data is normal ! lets move for the Model preparation.** 🚀

# %% [markdown]
# ### Find Correlations in Data Set

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(), annot=True);
plt.show()

# %% [markdown]
# # **Model Preparation**
#
# Spilt into X & Y

# %%
# separating the data and target
X = data.drop(columns=['Index'],axis=1)
y = data['Index']

# %%
print("The shape of X is " , X.shape)
print("The shape of Y is " , y.shape)
# Out:
# The shape of X is  (489, 3)
# The shape of Y is  (489,)

# %%
from sklearn.model_selection import train_test_split
# separating into train and testing
X_train, X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)
print("Shape of X_train is " ,X_train.shape)
print("Shape of X_test  is " ,X_test.shape)
print("Shape of Y_train is " ,Y_train.shape)
print("Shape of Y_test  is " ,Y_test.shape)
# Out:
# Shape of X_train is  (391, 3)
# Shape of X_test  is  (98, 3)
# Shape of Y_train is  (391,)
# Shape of Y_test  is  (98,)

# %%
# After statify Y train & test values
print(Y_train.value_counts())
print(Y_test.value_counts())
# Out:
# 5    156
# 4    102
# 2     55
# 3     51
# 1     16
# 0     11
# Name: Index, dtype: int64
# 5    39
# 4    26
# 2    14
# 3    13
# 1     4
# 0     2
# Name: Index, dtype: int64

# %% [markdown]
# # **Feature Scalilng**

# %%
# scaling the data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.99744572,  0.34561137,  0.06005576],
#        [ 1.00256082, -0.88905328, -0.03227112],
#        [-0.99744572,  0.28387814,  0.86022209],
#        ...,
#        [-0.99744572,  0.34561137, -0.61700805],
#        [ 1.00256082,  0.03694521,  1.38340776],
#        [-0.99744572,  0.90121046,  0.9833246 ]])

# %%
from sklearn.ensemble import RandomForestClassifier
randf=RandomForestClassifier(n_estimators=100)
randf.fit(X_train,Y_train)
y_pred=randf.predict(X_test)

# %%
randf.feature_importances_
# Out:
# array([0.01421488, 0.34727195, 0.63851317])

# %%
features = data.columns.values.tolist()[0:3] #Dropping Dependent Variable BMI
feature_pro = pd.Series(randf.feature_importances_,index=features).sort_values(ascending=False)

# %%
feature_pro
# Out:
# Weight    0.638513
# Height    0.347272
# Gender    0.014215
# dtype: float64

# %% [markdown]
# ## Feature Importances Vizualizing

# %%
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_pro, y=feature_pro.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **Model Training**
#
# **We will train different model after the evaluation of model we will select out best model for production.**
#
# 1.   Logistic Regression
# 2.   KNN
# 3.   SVC
# 3.   Decision Tree
# 4.   Random Forest Regressor
# 5.   XgBoost
# 6.   Gradient Boosting

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

lr = LogisticRegression()
lr.fit(X_train, Y_train)
y_pred = lr.predict(X_test)

lr_train_acc = accuracy_score(Y_train, lr.predict(X_train))
lr_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Logistic Regression Model is {lr_train_acc}")
print(f"Test Accuracy of Logistic Regression Model is {lr_test_acc}")
# Out:
# Training Accuracy of Logistic Regression Model is 0.8363171355498721
# Test Accuracy of Logistic Regression Model is 0.8367346938775511

# %%
# confusion matrix 
confusion_matrix(Y_test, y_pred)
# Out:
# array([[ 0,  1,  1,  0,  0,  0],
#        [ 0,  0,  4,  0,  0,  0],
#        [ 0,  0, 14,  0,  0,  0],
#        [ 0,  0,  4,  5,  4,  0],
#        [ 0,  0,  0,  0, 26,  0],
#        [ 0,  0,  0,  0,  2, 37]], dtype=int64)

# %%
# classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00         4
#            2       0.61      1.00      0.76        14
#            3       1.00      0.38      0.56        13
#            4       0.81      1.00      0.90        26
#            5       1.00      0.95      0.97        39
#
#     accuracy                           0.84        98
#    macro avg       0.57      0.56      0.53        98
# weighted avg       0.83      0.84      0.81        98
# C:\Users\AKILA\PycharmProjects\Murtaza's_Workshop\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AKILA\PycharmProjects\Murtaza's_Workshop\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AKILA\PycharmProjects\Murtaza's_Workshop\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## **SVC**

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, Y_train)

y_pred = svc.predict(X_test)

svc_train_acc = accuracy_score(Y_train, svc.predict(X_train))
svc_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of SVC Model is {svc_train_acc}")
print(f"Test Accuracy of SVC Model is {svc_test_acc}")
# Out:
# Training Accuracy of SVC Model is 0.8976982097186701
# Test Accuracy of SVC Model is 0.8673469387755102

# %%
# confusion matrix
confusion_matrix(Y_test, y_pred)
# Out:
# array([[ 1,  1,  0,  0,  0,  0],
#        [ 1,  1,  2,  0,  0,  0],
#        [ 0,  0, 13,  1,  0,  0],
#        [ 0,  0,  4,  8,  1,  0],
#        [ 0,  0,  0,  0, 25,  1],
#        [ 0,  0,  0,  0,  2, 37]], dtype=int64)

# %%
# classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.50      0.25      0.33         4
#            2       0.68      0.93      0.79        14
#            3       0.89      0.62      0.73        13
#            4       0.89      0.96      0.93        26
#            5       0.97      0.95      0.96        39
#
#     accuracy                           0.87        98
#    macro avg       0.74      0.70      0.71        98
# weighted avg       0.87      0.87      0.86        98

# %% [markdown]
# ## **DecisionTreeClassifier**

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)

y_pred = dtc.predict(X_test)

dtc_train_acc = accuracy_score(Y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Decision Tree Model is {dtc_train_acc}")
print(f"Test Accuracy of Decision Tree Model is {dtc_test_acc}")
# Out:
# Training Accuracy of Decision Tree Model is 1.0
# Test Accuracy of Decision Tree Model is 0.8469387755102041

# %%
# confusion matrix
confusion_matrix(Y_test, y_pred)
# Out:
# array([[ 2,  0,  0,  0,  0,  0],
#        [ 1,  3,  0,  0,  0,  0],
#        [ 1,  2, 10,  1,  0,  0],
#        [ 0,  0,  2,  7,  4,  0],
#        [ 0,  0,  0,  0, 23,  3],
#        [ 0,  0,  0,  0,  1, 38]], dtype=int64)

# %%
# classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.60      0.75      0.67         4
#            2       0.83      0.71      0.77        14
#            3       0.88      0.54      0.67        13
#            4       0.82      0.88      0.85        26
#            5       0.93      0.97      0.95        39
#
#     accuracy                           0.85        98
#    macro avg       0.76      0.81      0.76        98
# weighted avg       0.86      0.85      0.84        98

# %% [markdown]
# ## **Hyper parameter tuning**

# %%
# hyper parameter tuning

from sklearn.model_selection import GridSearchCV

grid_params = {
    'criterion' : ['gini', 'entropy'],

    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(dtc, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
# best parameters and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.8261927945472248

# %%
dtc = grid_search.best_estimator_
y_pred = dtc.predict(X_test)
dtc_train_acc = accuracy_score(Y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Decesion Tree Model is {dtc_train_acc}")
print(f"Test Accuracy of Decesion Tree Model is {dtc_test_acc}")
# Out:
# Training Accuracy of Decesion Tree Model is 0.9641943734015346
# Test Accuracy of Decesion Tree Model is 0.8571428571428571

# %% [markdown]
# **Visualization the DTC tree.**

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dtc,filled=True)
# Out:
# [Text(0.5246478873239436, 0.95, 'x[2] <= -0.725\nentropy = 2.15\nsamples = 391\nvalue = [11, 16, 55, 51, 102, 156]'),
#  Text(0.26936619718309857, 0.85, 'x[1] <= -0.21\nentropy = 2.135\nsamples = 112\nvalue = [11, 16, 50, 18, 16, 1]'),
#  Text(0.13732394366197184, 0.75, 'x[2] <= -1.294\nentropy = 1.79\nsamples = 51\nvalue = [1, 0, 19, 14, 16, 1]'),
#  Text(0.07042253521126761, 0.65, 'x[1] <= -1.136\nentropy = 0.998\nsamples = 23\nvalue = [1, 0, 17, 5, 0, 0]'),
#  Text(0.04225352112676056, 0.55, 'x[2] <= -1.525\nentropy = 0.954\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.028169014084507043, 0.45, 'x[1] <= -1.321\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.014084507042253521, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.04225352112676056, 0.35, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.056338028169014086, 0.45, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.09859154929577464, 0.55, 'x[1] <= -0.488\nentropy = 0.353\nsamples = 15\nvalue = [1, 0, 14, 0, 0, 0]'),
#  Text(0.08450704225352113, 0.45, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.11267605633802817, 0.45, 'x[1] <= -0.426\nentropy = 0.722\nsamples = 5\nvalue = [1, 0, 4, 0, 0, 0]'),
#  Text(0.09859154929577464, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.1267605633802817, 0.35, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.20422535211267606, 0.65, 'x[2] <= -0.971\nentropy = 1.431\nsamples = 28\nvalue = [0, 0, 2, 9, 16, 1]'),
#  Text(0.16901408450704225, 0.55, 'x[1] <= -1.229\nentropy = 1.248\nsamples = 16\nvalue = [0, 0, 1, 9, 6, 0]'),
#  Text(0.15492957746478872, 0.45, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.18309859154929578, 0.45, 'x[2] <= -1.048\nentropy = 1.041\nsamples = 12\nvalue = [0, 0, 1, 9, 2, 0]'),
#  Text(0.15492957746478872, 0.35, 'x[1] <= -0.426\nentropy = 0.544\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.14084507042253522, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.16901408450704225, 0.25, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2112676056338028, 0.35, 'x[1] <= -0.673\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.19718309859154928, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.22535211267605634, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.23943661971830985, 0.55, 'x[1] <= -1.753\nentropy = 0.817\nsamples = 12\nvalue = [0, 0, 1, 0, 10, 1]'),
#  Text(0.22535211267605634, 0.45, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.2535211267605634, 0.45, 'x[2] <= -0.879\nentropy = 0.469\nsamples = 10\nvalue = [0, 0, 1, 0, 9, 0]'),
#  Text(0.23943661971830985, 0.35, 'entropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.2676056338028169, 0.35, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.4014084507042254, 0.75, 'x[2] <= -1.156\nentropy = 1.688\nsamples = 61\nvalue = [10, 16, 31, 4, 0, 0]'),
#  Text(0.352112676056338, 0.65, 'x[1] <= 0.623\nentropy = 1.522\nsamples = 34\nvalue = [10, 16, 8, 0, 0, 0]'),
#  Text(0.323943661971831, 0.55, 'x[2] <= -1.463\nentropy = 0.961\nsamples = 13\nvalue = [0, 5, 8, 0, 0, 0]'),
#  Text(0.30985915492957744, 0.45, 'x[1] <= -0.056\nentropy = 0.863\nsamples = 7\nvalue = [0, 5, 2, 0, 0, 0]'),
#  Text(0.29577464788732394, 0.35, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.323943661971831, 0.35, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0]'),
#  Text(0.3380281690140845, 0.45, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.38028169014084506, 0.55, 'x[2] <= -1.586\nentropy = 0.998\nsamples = 21\nvalue = [10, 11, 0, 0, 0, 0]'),
#  Text(0.36619718309859156, 0.45, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0, 0, 0]'),
#  Text(0.39436619718309857, 0.45, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0, 0, 0]'),
#  Text(0.4507042253521127, 0.65, 'x[1] <= 0.562\nentropy = 0.605\nsamples = 27\nvalue = [0, 0, 23, 4, 0, 0]'),
#  Text(0.43661971830985913, 0.55, 'x[0] <= 0.003\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 3, 4, 0, 0]'),
#  Text(0.4225352112676056, 0.45, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4507042253521127, 0.45, 'x[1] <= 0.346\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.43661971830985913, 0.35, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4647887323943662, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.4647887323943662, 0.55, 'entropy = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(0.7799295774647887, 0.85, 'x[2] <= 0.66\nentropy = 1.463\nsamples = 279\nvalue = [0, 0, 5, 33, 86, 155]'),
#  Text(0.6302816901408451, 0.75, 'x[1] <= -0.241\nentropy = 1.675\nsamples = 154\nvalue = [0, 0, 5, 33, 70, 46]'),
#  Text(0.5352112676056338, 0.65, 'x[2] <= 0.014\nentropy = 0.782\nsamples = 56\nvalue = [0, 0, 0, 0, 13, 43]'),
#  Text(0.5211267605633803, 0.55, 'x[1] <= -0.642\nentropy = 0.96\nsamples = 34\nvalue = [0, 0, 0, 0, 13, 21]'),
#  Text(0.5070422535211268, 0.45, 'x[2] <= -0.309\nentropy = 0.85\nsamples = 29\nvalue = [0, 0, 0, 0, 8, 21]'),
#  Text(0.49295774647887325, 0.35, 'x[1] <= -1.568\nentropy = 0.991\nsamples = 18\nvalue = [0, 0, 0, 0, 8, 10]'),
#  Text(0.4788732394366197, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 6]'),
#  Text(0.5070422535211268, 0.25, 'x[2] <= -0.494\nentropy = 0.918\nsamples = 12\nvalue = [0, 0, 0, 0, 8, 4]'),
#  Text(0.49295774647887325, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.5211267605633803, 0.15, 'x[1] <= -0.889\nentropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 0, 2, 4]'),
#  Text(0.5070422535211268, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.5352112676056338, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5211267605633803, 0.35, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 0, 11]'),
#  Text(0.5352112676056338, 0.45, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.5492957746478874, 0.55, 'entropy = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 0, 22]'),
#  Text(0.7253521126760564, 0.65, 'x[2] <= 0.075\nentropy = 1.357\nsamples = 98\nvalue = [0, 0, 5, 33, 57, 3]'),
#  Text(0.6338028169014085, 0.55, 'x[1] <= 0.438\nentropy = 1.317\nsamples = 57\nvalue = [0, 0, 5, 31, 21, 0]'),
#  Text(0.5915492957746479, 0.45, 'x[2] <= -0.494\nentropy = 0.748\nsamples = 20\nvalue = [0, 0, 1, 2, 17, 0]'),
#  Text(0.5774647887323944, 0.35, 'x[1] <= 0.16\nentropy = 1.379\nsamples = 7\nvalue = [0, 0, 1, 2, 4, 0]'),
#  Text(0.5633802816901409, 0.25, 'x[1] <= -0.117\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.5492957746478874, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5774647887323944, 0.15, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.5915492957746479, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6056338028169014, 0.35, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(0.676056338028169, 0.45, 'x[2] <= -0.14\nentropy = 0.969\nsamples = 37\nvalue = [0, 0, 4, 29, 4, 0]'),
#  Text(0.6338028169014085, 0.35, 'x[1] <= 1.117\nentropy = 0.619\nsamples = 26\nvalue = [0, 0, 4, 22, 0, 0]'),
#  Text(0.6197183098591549, 0.25, 'entropy = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.647887323943662, 0.25, 'x[2] <= -0.448\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.6338028169014085, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.6619718309859155, 0.15, 'x[1] <= 1.426\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.647887323943662, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.676056338028169, 0.05, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7183098591549296, 0.35, 'x[1] <= 0.994\nentropy = 0.946\nsamples = 11\nvalue = [0, 0, 0, 7, 4, 0]'),
#  Text(0.704225352112676, 0.25, 'x[1] <= 0.747\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.6901408450704225, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.7183098591549296, 0.15, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7323943661971831, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8169014084507042, 0.55, 'x[1] <= 0.068\nentropy = 0.653\nsamples = 41\nvalue = [0, 0, 0, 2, 36, 3]'),
#  Text(0.7887323943661971, 0.45, 'x[2] <= 0.368\nentropy = 1.406\nsamples = 8\nvalue = [0, 0, 0, 1, 4, 3]'),
#  Text(0.7746478873239436, 0.35, 'x[1] <= -0.117\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.7605633802816901, 0.25, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7887323943661971, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8028169014084507, 0.35, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.8450704225352113, 0.45, 'x[2] <= 0.168\nentropy = 0.196\nsamples = 33\nvalue = [0, 0, 0, 1, 32, 0]'),
#  Text(0.8309859154929577, 0.35, 'x[1] <= 0.778\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(0.8169014084507042, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.8450704225352113, 0.25, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8591549295774648, 0.35, 'entropy = 0.0\nsamples = 27\nvalue = [0, 0, 0, 0, 27, 0]'),
#  Text(0.9295774647887324, 0.75, 'x[1] <= 0.932\nentropy = 0.552\nsamples = 125\nvalue = [0, 0, 0, 0, 16, 109]'),
#  Text(0.9014084507042254, 0.65, 'x[1] <= 0.623\nentropy = 0.138\nsamples = 103\nvalue = [0, 0, 0, 0, 2, 101]'),
#  Text(0.8873239436619719, 0.55, 'entropy = 0.0\nsamples = 89\nvalue = [0, 0, 0, 0, 0, 89]'),
#  Text(0.9154929577464789, 0.55, 'x[2] <= 1.014\nentropy = 0.592\nsamples = 14\nvalue = [0, 0, 0, 0, 2, 12]'),
#  Text(0.9014084507042254, 0.45, 'x[2] <= 0.968\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 0, 2, 2]'),
#  Text(0.8873239436619719, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.9154929577464789, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.9295774647887324, 0.45, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 0, 10]'),
#  Text(0.9577464788732394, 0.65, 'x[2] <= 0.983\nentropy = 0.946\nsamples = 22\nvalue = [0, 0, 0, 0, 14, 8]'),
#  Text(0.9436619718309859, 0.55, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.971830985915493, 0.55, 'x[1] <= 1.611\nentropy = 0.985\nsamples = 14\nvalue = [0, 0, 0, 0, 6, 8]'),
#  Text(0.9577464788732394, 0.45, 'x[2] <= 1.306\nentropy = 0.845\nsamples = 11\nvalue = [0, 0, 0, 0, 3, 8]'),
#  Text(0.9436619718309859, 0.35, 'x[2] <= 1.214\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 0, 0, 3, 4]'),
#  Text(0.9295774647887324, 0.25, 'x[1] <= 1.056\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 0, 1, 4]'),
#  Text(0.9154929577464789, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.9436619718309859, 0.15, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.9577464788732394, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.971830985915493, 0.35, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.9859154929577465, 0.45, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]')]

# %%
data.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %% [markdown]
# ## **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion = 'gini', max_depth = 3, max_features = 'sqrt', min_samples_leaf = 2, min_samples_split = 4, n_estimators = 180)
rand_clf.fit(X_train, Y_train)

y_pred = rand_clf.predict(X_test)

rand_clf_train_acc = accuracy_score(Y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of Random Forest Model is {rand_clf_train_acc}")
print(f"Test Accuracy of Random Forest Model is {rand_clf_test_acc}")
# Out:
# Training Accuracy of Random Forest Model is 0.7263427109974424
# Test Accuracy of Random Forest Model is 0.7142857142857143

# %% [markdown]
# ## **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
k_model = KNeighborsClassifier(n_neighbors=16)
kfitModel = k_model.fit(X_train, Y_train)

# accuracy score on training data

kX_train_prediction = kfitModel.predict(X_train)
training_data_accuray = accuracy_score(kX_train_prediction,Y_train)
print('Accuracy on training data  : ', training_data_accuray)

# accuracy score on testing data
kX_test_prediction = kfitModel.predict(X_test)
kx_lgr_test_data_accuray = accuracy_score(kX_test_prediction,Y_test)
print('Accuracy on test data      : ', kx_lgr_test_data_accuray)
# Out:
# Accuracy on training data  :  0.8593350383631714
# Accuracy on test data      :  0.8163265306122449

# %% [markdown]
# ## **XGB Classifier**

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(booster = 'gblinear', learning_rate = 1, n_estimators = 10)
xgb.fit(X_train, Y_train)

y_pred = xgb.predict(X_test)

xgb_train_acc = accuracy_score(Y_train, xgb.predict(X_train))
xgb_test_acc = accuracy_score(Y_test, y_pred)

print(f"Training Accuracy of XGB Model is {xgb_train_acc}")
print(f"Test Accuracy of XGB Model is {xgb_test_acc}")
# Out:
# Training Accuracy of XGB Model is 0.7979539641943734
# Test Accuracy of XGB Model is 0.8163265306122449

# %%
models = ['Logistic Regression', 'KNN', 'SVC', 'Decision Tree', 'Random Forest', 'XgBoost']
scores = [lr_test_acc, kx_lgr_test_data_accuray, svc_test_acc, dtc_test_acc, rand_clf_test_acc, xgb_test_acc]

models = pd.DataFrame({'Model' : models, 'Score' : scores})


models.sort_values(by = 'Score', ascending = False)
# Out:
#                  Model     Score
# 2                  SVC  0.867347
# 3        Decision Tree  0.857143
# 0  Logistic Regression  0.836735
# 1                  KNN  0.816327
# 5              XgBoost  0.816327
# 4        Random Forest  0.714286

# %%
plt.figure(figsize = (18, 8))

sns.barplot(x = 'Model', y = 'Score', data = models)
plt.show()

# %% [markdown]
# ### ***SVC gives us the best result so we will save this model for production but it overfit.***

# %%
import pickle

# %%
# save the model to disk
filename = 'BMI_model.sav'
pickle.dump(models, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model
# Out:
#                  Model     Score
# 0  Logistic Regression  0.836735
# 1                  KNN  0.816327
# 2                  SVC  0.867347
# 3        Decision Tree  0.857143
# 4        Random Forest  0.714286
# 5              XgBoost  0.816327

# %% [markdown]
# ## Create Pickle File for lr Model

# %%
import pickle
# open a file, where you ant to store the data
file = open('BMI_model.pkl', 'wb')

# dump information to that file
pickle.dump(lr, file)  #Selecting svm as the Model because of Giving highest Accuracy

# %%
#Reading the Pickle file for to certify model was imported Successfully
model = open('BMI_model.pkl','rb')
lrModel= pickle.load(model)

# %%
# Prediction Parameters testing using the imported Model
y_prediction = lrModel.predict(X_test)

# %%
svc_acc = accuracy_score(Y_test, y_prediction)

# %%
svc_acc
# Out:
# 0.8367346938775511

# %% [markdown]
# ## ***.hy file***

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import joblib

# %%
# Save the model to a .hy file
file = open('BMI_model.hy', 'wb')
joblib.dump(lr, file)
# file.close()

# Load the model from the .hy file
model = open('BMI_model.hy', 'rb')
loaded_model = joblib.load(model)
# model.close()

# Assuming X_test is your test data
predictions = loaded_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, predictions)
print(f"Accuracy of the loaded model is {accuracy}")
# Out:
# Accuracy of the loaded model is 0.8367346938775511

# %% [markdown]
# **So this will Verify that Our Imported hy file provides the desired out put for the Lung Cancer Dataset for Prdiction Purpose**

# %%
import numpy as np
import joblib

# %%
loaded_model = joblib.load('BMI_model.hy')

# %%
X_New = np.array([1, 191, 54])  # level 2
X_New = np.reshape(X_New, (1, -1))

# %%
y_New = loaded_model.predict(X_New)

# %%
print("y_New- ",y_New)
# Out:
# y_New-  [1]
